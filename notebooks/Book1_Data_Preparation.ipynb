# %%
import pandas as pd

# %%
sentiment = pd.read_csv("/content/sentiment.csv")
data = pd.read_csv("/content/data.csv")

# %%
sentiment
# Out:
#        timestamp  value classification        date
# 0     1517463000     30           Fear  2018-02-01
# 1     1517549400     15   Extreme Fear  2018-02-02
# 2     1517635800     40           Fear  2018-02-03
# 3     1517722200     24   Extreme Fear  2018-02-04
# 4     1517808600     11   Extreme Fear  2018-02-05
# ...          ...    ...            ...         ...
# 2639  1745818200     54        Neutral  2025-04-28
# 2640  1745904600     60          Greed  2025-04-29
# 2641  1745991000     56          Greed  2025-04-30
# 2642  1746077400     53        Neutral  2025-05-01
# 2643  1746163800     67          Greed  2025-05-02
#
# [2644 rows x 4 columns]

# %%
data
# Out:
#                                            Account      Coin  Execution Price  \
# 0       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9769
# 1       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9800
# 2       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9855
# 3       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9874
# 4       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9894
# ...                                            ...       ...              ...
# 211219  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211220  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211221  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211222  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211223  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
#
# ...

# %%
sentiment = sentiment.copy()

# %%
sentiment['sent_dt_unix_s'] = pd.to_datetime(sentiment['timestamp'], unit='s', errors='coerce')

# %%
mask_ms = sentiment['sent_dt_unix_s'].isna() & sentiment['timestamp'].notna()
if mask_ms.any():
    sentiment.loc[mask_ms, 'sent_dt_unix_s'] = pd.to_datetime(sentiment.loc[mask_ms, 'timestamp'], unit='ms', errors='coerce')

# %%
sentiment['sent_dt_str'] = pd.to_datetime(sentiment['date'], errors='coerce')

# %%
sentiment['sent_dt'] = sentiment['sent_dt_unix_s'].combine_first(sentiment['sent_dt_str'])

# %%
sentiment['date_gran'] = sentiment['sent_dt'].dt.floor('D')
sentiment['date_key'] = sentiment['date_gran'].dt.strftime('%Y-%m-%d')

# %%
print("Sentiment data shape:", sentiment.shape)
print("Data types:\n", sentiment.dtypes)

print("\nFirst 8 rows:")
print(sentiment.head(8))

missing_count = sentiment['sent_dt'].isna().sum()
print(f"\nMissing 'sent_dt': {missing_count} out of {len(sentiment)}")

if missing_count > 0:
    print("\nSample rows with missing 'sent_dt':")
    display(sentiment[sentiment['sent_dt'].isna()].head(10))
# Out:
# Sentiment data shape: (2644, 9)
# Data types:
#  timestamp                  int64
# value                      int64
# classification            object
# date                      object
# sent_dt_unix_s    datetime64[ns]
# sent_dt_str       datetime64[ns]
# sent_dt           datetime64[ns]
# date_gran         datetime64[ns]
# date_key                  object
# dtype: object
#
# First 8 rows:
#     timestamp  value classification        date      sent_dt_unix_s  \
# 0  1517463000     30           Fear  2018-02-01 2018-02-01 05:30:00
# 1  1517549400     15   Extreme Fear  2018-02-02 2018-02-02 05:30:00
# 2  1517635800     40           Fear  2018-02-03 2018-02-03 05:30:00
# 3  1517722200     24   Extreme Fear  2018-02-04 2018-02-04 05:30:00
# 4  1517808600     11   Extreme Fear  2018-02-05 2018-02-05 05:30:00
# 5  1517895000      8   Extreme Fear  2018-02-06 2018-02-06 05:30:00
# 6  1517981400     36           Fear  2018-02-07 2018-02-07 05:30:00
# ...

# %%
sentiment = sentiment

# %%
data = data.copy()

# %%
data['trade_dt_epoch_ms'] = pd.to_datetime(data['Timestamp'], unit='ms', errors='coerce')
data['trade_dt_epoch_s']  = pd.to_datetime(data['Timestamp'], unit='s',  errors='coerce')

# %%
if 'Timestamp IST' in data.columns:
    data['trade_dt_ist'] = pd.to_datetime(data['Timestamp IST'], dayfirst=True, errors='coerce')
else:
    data['trade_dt_ist'] = pd.Series([pd.NaT]*len(data), index=data.index)

# %%
fallback_cols = [c for c in ['created_at', 'timestamp_str', 'time'] if c in data.columns]
if fallback_cols:
    # try the first fallback column
    data['trade_dt_fallback'] = pd.to_datetime(data[fallback_cols[0]], errors='coerce')
else:
    data['trade_dt_fallback'] = pd.Series([pd.NaT]*len(data), index=data.index)

# %%
data['trade_dt'] = data['trade_dt_ist'].combine_first(data['trade_dt_epoch_ms']) \
                                       .combine_first(data['trade_dt_epoch_s']) \
                                       .combine_first(data['trade_dt_fallback'])

# %%
data['date_gran'] = data['trade_dt'].dt.floor('D')
data['date_key']  = data['date_gran'].dt.strftime('%Y-%m-%d')

# %%
print("Data shape:", data.shape)

cols_to_check = ['Timestamp', 'Timestamp IST'] if 'Timestamp IST' in data.columns else ['Timestamp']
print("Data types for key columns:\n", data.dtypes[cols_to_check])

key_cols = ['Timestamp', 'Timestamp IST', 'trade_dt_epoch_ms', 'trade_dt_epoch_s',
            'trade_dt_ist', 'trade_dt', 'date_key']
key_cols = [c for c in key_cols if c in data.columns]

print("\nFirst 10 rows (key columns):")
display(data[key_cols].head(10))

missing_trade_dt = data['trade_dt'].isna().sum()
print(f"\nMissing 'trade_dt': {missing_trade_dt} out of {len(data)}")

if missing_trade_dt > 0:
    print("\nSample rows with missing 'trade_dt':")
    display(data[data['trade_dt'].isna()].head(10))
# Out:
# Data shape: (211224, 23)
# Data types for key columns:
#  Timestamp        float64
# Timestamp IST     object
# dtype: object
#
# First 10 rows (key columns):
#       Timestamp     Timestamp IST   trade_dt_epoch_ms trade_dt_epoch_s  \
# 0  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 1  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 2  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 3  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 4  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 5  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 6  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 7  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 8  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 9  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
#
# ...

# %%
print("\nTrade datetime min/max (non-null):")
print(data['trade_dt'].min(), "to", data['trade_dt'].max())
# Out:
# Trade datetime min/max (non-null):
# 2023-05-01 01:06:00 to 2025-05-01 12:13:00

# %%
data=data

# %%
import numpy as np

# %%
data['trade_dt_epoch_ms'] = pd.to_datetime(data['Timestamp'], unit='ms', errors='coerce')
data['trade_dt_epoch_s']  = pd.to_datetime(data['Timestamp'], unit='s', errors='coerce')
data['trade_dt_ist'] = pd.to_datetime(data['Timestamp IST'], dayfirst=True, errors='coerce')

# %%
print("Epoch-ms range:", data['trade_dt_epoch_ms'].min(), "to", data['trade_dt_epoch_ms'].max())
print("Epoch-s  range:", data['trade_dt_epoch_s'].min(), "to", data['trade_dt_epoch_s'].max())
print("IST-string range:", data['trade_dt_ist'].min(), "to", data['trade_dt_ist'].max())
# Out:
# Epoch-ms range: 2023-03-28 10:40:00 to 2025-06-15 15:06:40
# Epoch-s  range: NaT to NaT
# IST-string range: 2023-05-01 01:06:00 to 2025-05-01 12:13:00

# %%
def plausible(series, start='2010-01-01', end='2035-12-31'):
    s, e = pd.to_datetime(start), pd.to_datetime(end)
    return series.between(s, e).mean()

# %%
print("Plausible fraction ms:", plausible(data['trade_dt_epoch_ms']))
print("Plausible fraction s :", plausible(data['trade_dt_epoch_s']))
# Out:
# Plausible fraction ms: 1.0
# Plausible fraction s : 0.0

# %%
mask_ist = data['trade_dt_ist'].notna()
data.loc[mask_ist, 'diff_days_ms_vs_ist'] = (data.loc[mask_ist, 'trade_dt_epoch_ms'] - data.loc[mask_ist, 'trade_dt_ist']).dt.total_seconds() / 86400
data.loc[mask_ist, 'diff_days_s_vs_ist']  = (data.loc[mask_ist, 'trade_dt_epoch_s'] - data.loc[mask_ist, 'trade_dt_ist']).dt.total_seconds() / 86400

# %%
print("Median diff (epoch-ms – IST):", data['diff_days_ms_vs_ist'].median(skipna=True))
print("Median diff (epoch-s – IST): ", data['diff_days_s_vs_ist'].median(skipna=True))
# Out:
# Median diff (epoch-ms – IST): -11.628472222222221
# Median diff (epoch-s – IST):  nan

# %%
THRESH = 2
mask_large_diff = mask_ist & data['diff_days_ms_vs_ist'].abs().gt(THRESH)
print("Rows where epoch-ms disagrees with IST by >2 days:", mask_large_diff.sum())
# Out:
# Rows where epoch-ms disagrees with IST by >2 days: 204159

# %%
cols = ['Timestamp', 'Timestamp IST', 'trade_dt_epoch_ms', 'trade_dt_epoch_s', 'trade_dt_ist', 'diff_days_ms_vs_ist', 'diff_days_s_vs_ist']
display(data.loc[mask_large_diff, cols].head(10))
# Out:
#       Timestamp     Timestamp IST   trade_dt_epoch_ms trade_dt_epoch_s  \
# 0  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 1  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 2  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 3  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 4  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 5  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 6  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 7  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 8  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
# 9  1.730000e+12  02-12-2024 22:50 2024-10-27 03:33:20              NaT
#
#          trade_dt_ist  diff_days_ms_vs_ist  diff_days_s_vs_ist
# 0 2024-12-02 22:50:00           -36.803241                 NaN
# ...

# %%
import pytz

# %%
def plausible_fraction(series, start='2010-01-01', end='2035-12-31'):
    s, e = pd.to_datetime(start), pd.to_datetime(end)
    return series.between(s, e).mean()

# %%
frac_ms = plausible_fraction(data['trade_dt_epoch_ms'])
frac_s  = plausible_fraction(data['trade_dt_epoch_s'])
print("Plausible fraction (ms):", frac_ms, " | (s):", frac_s)
# Out:
# Plausible fraction (ms): 1.0  | (s): 0.0

# %%
use_ms = frac_ms >= frac_s
data['trade_dt_epoch_best'] = data['trade_dt_epoch_ms'] if use_ms else data['trade_dt_epoch_s']
print("→ Using epoch as", "milliseconds" if use_ms else "seconds")
# Out:
# → Using epoch as milliseconds

# %%
k_tz = pytz.timezone('Asia/Kolkata')
data['trade_dt_ist_local'] = pd.to_datetime(data['Timestamp IST'], dayfirst=True, errors='coerce').dt.tz_localize(k_tz, ambiguous='NaT', nonexistent='NaT')
data['trade_dt'] = data['trade_dt_ist_local'].combine_first(pd.to_datetime(data['trade_dt_epoch_best'], utc=True, errors='coerce'))
# Out:
# /tmp/ipython-input-362181456.py:3: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   data['trade_dt'] = data['trade_dt_ist_local'].combine_first(pd.to_datetime(data['trade_dt_epoch_best'], utc=True, errors='coerce'))

# %%
data['trade_dt_utc'] = data['trade_dt'].dt.tz_convert('UTC') #normalize

# %%
data['date_key_utc'] = data['trade_dt_utc'].dt.strftime('%Y-%m-%d')

# %%
data['date_key_ist'] = data['trade_dt_utc'].dt.tz_convert('Asia/Kolkata').dt.strftime('%Y-%m-%d')

# %%
print("Trade datetime range (UTC):", data['trade_dt_utc'].min(), "→", data['trade_dt_utc'].max())
print("Unique daily keys (UTC):", data['date_key_utc'].nunique())
# Out:
# Trade datetime range (UTC): 2023-04-30 19:36:00+00:00 → 2025-05-01 06:43:00+00:00
# Unique daily keys (UTC): 476

# %% [markdown]
# Merging datasets

# %%
sentiment['date'] = pd.to_datetime(sentiment['date'], errors='coerce')
sentiment['date_key'] = sentiment['date'].dt.strftime('%Y-%m-%d')

# %%
merged = data.merge(
    sentiment[['date_key', 'value', 'classification']],
    left_on='date_key_utc', right_on='date_key',
    how='left', validate='m:1'
)

print("Merged shape:", merged.shape)
display(merged[['Timestamp IST', 'trade_dt_utc', 'value', 'classification']].head())
# Out:
# Merged shape: (211224, 33)
#       Timestamp IST              trade_dt_utc  value classification
# 0  02-12-2024 22:50 2024-12-02 17:20:00+00:00     80  Extreme Greed
# 1  02-12-2024 22:50 2024-12-02 17:20:00+00:00     80  Extreme Greed
# 2  02-12-2024 22:50 2024-12-02 17:20:00+00:00     80  Extreme Greed
# 3  02-12-2024 22:50 2024-12-02 17:20:00+00:00     80  Extreme Greed
# 4  02-12-2024 22:50 2024-12-02 17:20:00+00:00     80  Extreme Greed

# %% [markdown]
# Save

# %%
sentiment.to_csv("sentiment_cleaned.csv", index=False)
data.to_csv("data_cleaned.csv", index=False)
merged.to_csv("merged_trades_sentiment.csv", index=False)

print("Files saved in the Colab environment:")
# !ls -lh *.csv
# Out:
# Files saved in the Colab environment:
# -rw-r--r-- 1 root root  90M Oct 23 16:26 data_cleaned.csv
# -rw-r--r-- 1 root root  46M Oct 23 15:02 data.csv
# -rw-r--r-- 1 root root  95M Oct 23 16:27 merged_trades_sentiment.csv
# -rw-r--r-- 1 root root 275K Oct 23 16:26 sentiment_cleaned.csv
# -rw-r--r-- 1 root root  89K Oct 23 15:01 sentiment.csv

# %%
from google.colab import files

# %%
files.download("sentiment_cleaned.csv")

# %%
files.download("data_cleaned.csv")

# %%
files.download("merged_trades_sentiment.csv")
